# %% [markdown]
# Creating a cleared dataset for supervised learning out of the annotations

# %%
import platform

from constants import COLLECTION_NAME, FOLDER_NAME, PATH_TO_BRAT


operating_system = platform.system()
slash = "\\" if operating_system == "Windows" else "/"
collection_path = PATH_TO_BRAT + slash + FOLDER_NAME + slash
collection_path += COLLECTION_NAME + slash if COLLECTION_NAME else ""

# %%
from Dataset import Dataset


dataset = Dataset(path_to_collection=collection_path)
dataset.to_json("../data/", "test.json")
dataset.dataset
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\albbl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\albbl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\albbl\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                  text
# 0   Genetic risk for attention-deficit/hyperactivi...  \
# 1   Attention-deficit/hyperactivity disorder (ADHD...
# 2   However, these findings rely primarily on elec...
# 3   Alternatively, this study aimed to determine w...
# 4   We calculated a weighted ADHD-PRS in 212 CU in...
# 5   Linear mixed-effects models were used to test ...
# 6   Additionally, higher ADHD-PRS was associated w...
# 7   Our results suggest that genetic liability for...
# 8   Findings were mostly observed in Aβ-positive i...
# 9   The Author(s), under exclusive licence to Spri...
# 10  Impact of Orthopaedic Surgeons on National Ins...
# 11  The National Institutes of Health (NIH) remain...
# 12  The Research Portfolio Online Reporting Tools ...
# 13  A total of 489 grants were awarded, totaling $...
# 14  Alzheimer disease received the most funding ($...
# 15  The R01 grant mechanism was the predominant so...
# 16  Departments of orthopaedic surgery were awarde...
# 17  There were no significant differences in NIH f...
# 18  There is a paucity of orthopaedic surgeon repr...
# 19  Additional research is needed to understand th...
# 20  Copyright © 2022 by The Journal of Bone and Jo...
# 21  Further co-expression network analysis reveale...
#
#                                                  drug      drug_indices_start
# 0     [disorder, Alzheimer, disease, pathophysiology]     [49, 104, 116, 124]  \
# 1   [Attention-deficit/hyperactivity, disorder, Al...  [0, 32, 134, 146, 155]
# 2                                           [disease]                   [104]
# 3                               [AD, pathophysiology]              [211, 214]
# 4                                         [diagnosis]                    [75]
# 5                                                [AD]                    [93]
# 6                                           [atrophy]                   [101]
# 7                               [AD, pathophysiology]              [118, 121]
# 8                                         [pathology]                   [159]
# 9                                  [Springer, Nature]                [42, 51]
# 10                           [Orthopaedic, Hip, Knee]            [10, 76, 84]
# 11                                           [United]                   [117]
# 12               [Portfolio, RePORTER, awarded, 2010]      [13, 72, 132, 203]
# 13                                          [awarded]                    [27]
# 14                        [Alzheimer, disease, palsy]             [0, 10, 89]
# 15                          [Mayo, Clinic, Minnesota]            [68, 73, 92]
# 16                             [Departments, awarded]                 [0, 40]
# 17                                           [Hirsch]                   [166]
# 18                                 [surgeon, awarded]                [34, 74]
# 19                                          [surgeon]                   [105]
# 20                           [Journal, Bone, Surgery]            [24, 35, 50]
# 21                                   [keratinization]                   [166]
#
#            drug_indices_end
# 0       [57, 113, 123, 139]
# 1   [31, 40, 143, 153, 157]
# 2                     [111]
# 3                [213, 229]
# 4                      [84]
# 5                      [95]
# 6                     [108]
# 7                [120, 136]
# 8                     [168]
# 9                  [50, 57]
# 10             [21, 79, 88]
# 11                    [123]
# 12       [22, 80, 139, 207]
# 13                     [34]
# 14              [9, 17, 94]
# 15            [72, 79, 101]
# 16                 [11, 47]
# 17                    [172]
# 18                 [41, 81]
# 19                    [112]
# 20             [31, 39, 57]
# 21                    [180]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(dataset.dataset, random_state=42)
test
# Out:
#                                                  text
# 0   Genetic risk for attention-deficit/hyperactivi...  \
# 13  A total of 489 grants were awarded, totaling $...
# 8   Findings were mostly observed in Aβ-positive i...
# 1   Attention-deficit/hyperactivity disorder (ADHD...
# 15  The R01 grant mechanism was the predominant so...
# 5   Linear mixed-effects models were used to test ...
#
#                                                  drug      drug_indices_start
# 0     [disorder, Alzheimer, disease, pathophysiology]     [49, 104, 116, 124]  \
# 13                                          [awarded]                    [27]
# 8                                         [pathology]                   [159]
# 1   [Attention-deficit/hyperactivity, disorder, Al...  [0, 32, 134, 146, 155]
# 15                          [Mayo, Clinic, Minnesota]            [68, 73, 92]
# 5                                                [AD]                    [93]
#
#            drug_indices_end
# 0       [57, 113, 123, 139]
# 13                     [34]
# 8                     [168]
# 1   [31, 40, 143, 153, 157]
# 15            [72, 79, 101]
# 5                      [95]
